# %%
import numpy as np
import pandas as pd
import pytz
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5f52e443b16c> in <module>
#       3 import pytz
#       4 import datetime
# ----> 5 import tqdm
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 1.4 MB/s eta 0:00:011
# Installing collected packages: tqdm
# Successfully installed tqdm-4.60.0

# %%
import tqdm

# %%
data = pd.read_csv('minuteData_NbTicksMin25_BusDay100_2020-12-31.csv')
data.head()
# Out:
#                    timeStamp  TSLA_open  AAPL_open  NVDA_open  ORCL_open  \
# 0  2020-08-14 09:30:00-04:00   332.9980   114.8288   461.2000     54.030
# 1  2020-08-14 09:31:00-04:00   330.6161   114.7500   461.2800     53.865
# 2  2020-08-14 09:32:00-04:00   331.2920   114.6325   461.8016     53.810
# 3  2020-08-14 09:33:00-04:00   332.9500   114.6575   463.7550     53.890
# 4  2020-08-14 09:34:00-04:00   331.6272   114.4225   462.0636     53.960
#
#    SPY_open  MSFT_open  C_open   FB_open  QQQ_open  ...  INTC_open  PFE_open  \
# 0   336.410     208.76  52.450  262.3050    273.01  ...     48.730   38.0100
# 1   336.420     208.93  52.565  261.9600    273.03  ...     48.800   38.0600
# 2   336.160     208.40  52.700  262.1600    272.64  ...     48.780   37.9900
# 3   336.415     208.92  52.560  262.3400    273.04  ...     48.870   37.9618
# 4   336.130     208.93  52.470  261.8229    272.80  ...     48.795   38.0000
#
#    BAC_open  NFLX_open  MU_open  XOM_open  GILD_open  SNAP_open  GE_open  \
# 0   26.0600    482.820   45.600   42.6000     68.090    21.9000   6.5400
# 1   26.1200    483.250   45.550   42.6608     68.170    21.9901   6.5300
# 2   26.1973    482.760   45.495   42.7500     68.120    21.9900   6.5500
# 3   26.1950    484.705   45.470   42.9100     68.255    22.0250   6.5499
# 4   26.1300    485.080   45.340   42.8300     68.200    22.0150   6.5450
#
#    IWM_open
# 0    156.28
# 1    156.47
# 2    156.50
# 3    156.67
# 4    156.42
#
# [5 rows x 26 columns]

# %%
type(data['timeStamp'][0])
# Out:
# str

# %%
data['timeStamp'] = pd.to_datetime(data['timeStamp'])

# %%
data.head()
# Out:
#                    timeStamp  TSLA_open  AAPL_open  NVDA_open  ORCL_open  \
# 0  2020-08-14 09:30:00-04:00   332.9980   114.8288   461.2000     54.030
# 1  2020-08-14 09:31:00-04:00   330.6161   114.7500   461.2800     53.865
# 2  2020-08-14 09:32:00-04:00   331.2920   114.6325   461.8016     53.810
# 3  2020-08-14 09:33:00-04:00   332.9500   114.6575   463.7550     53.890
# 4  2020-08-14 09:34:00-04:00   331.6272   114.4225   462.0636     53.960
#
#    SPY_open  MSFT_open  C_open   FB_open  QQQ_open  ...  INTC_open  PFE_open  \
# 0   336.410     208.76  52.450  262.3050    273.01  ...     48.730   38.0100
# 1   336.420     208.93  52.565  261.9600    273.03  ...     48.800   38.0600
# 2   336.160     208.40  52.700  262.1600    272.64  ...     48.780   37.9900
# 3   336.415     208.92  52.560  262.3400    273.04  ...     48.870   37.9618
# 4   336.130     208.93  52.470  261.8229    272.80  ...     48.795   38.0000
#
#    BAC_open  NFLX_open  MU_open  XOM_open  GILD_open  SNAP_open  GE_open  \
# 0   26.0600    482.820   45.600   42.6000     68.090    21.9000   6.5400
# 1   26.1200    483.250   45.550   42.6608     68.170    21.9901   6.5300
# 2   26.1973    482.760   45.495   42.7500     68.120    21.9900   6.5500
# 3   26.1950    484.705   45.470   42.9100     68.255    22.0250   6.5499
# 4   26.1300    485.080   45.340   42.8300     68.200    22.0150   6.5450
#
#    IWM_open
# 0    156.28
# 1    156.47
# 2    156.50
# 3    156.67
# 4    156.42
#
# [5 rows x 26 columns]

# %%
cols = data.columns

# %%
cols = cols.drop("timeStamp")
cols
# Out:
# Index(['TSLA_open', 'AAPL_open', 'NVDA_open', 'ORCL_open', 'SPY_open',
#        'MSFT_open', 'C_open', 'FB_open', 'QQQ_open', 'AMZN_open', 'WFC_open',
#        'SQQQ_open', 'WMT_open', 'UBER_open', 'BA_open', 'INTC_open',
#        'PFE_open', 'BAC_open', 'NFLX_open', 'MU_open', 'XOM_open', 'GILD_open',
#        'SNAP_open', 'GE_open', 'IWM_open'],
#       dtype='object')

# %%
cols = [x[:-5] for x in cols]
cols
# Out:
# ['TSLA',
#  'AAPL',
#  'NVDA',
#  'ORCL',
#  'SPY',
#  'MSFT',
#  'C',
#  'FB',
#  'QQQ',
#  'AMZN',
#  'WFC',
#  'SQQQ',
#  'WMT',
#  'UBER',
#  'BA',
#  'INTC',
#  'PFE',
#  'BAC',
#  'NFLX',
#  'MU',
#  'XOM',
#  'GILD',
#  'SNAP',
#  'GE',
#  'IWM']

# %%
log_returns = pd.DataFrame(columns = [x+'_log_return' for x in cols])
vol_5 = pd.DataFrame(columns = [x+'_vol_5' for x in cols])
vol_30 = pd.DataFrame(columns = [x+'_vol_30' for x in cols])

# %%
for index, row in tqdm.tqdm(data.iterrows(), total = data.shape[0]):
    log_return = []
    v_5 = []
    v_30 = []
    for c in cols:
        if index > 0:
            log_return.append(np.log(data[c+'_open'][index]/data[c+'_open'][index-1]))
        if index > 3:
            v_5.append(np.std(data[c+'_open'][index-4:index+1]))
        if index > 28:
            v_30.append(np.std(data[c+'_open'][index-29:index+1])) 
            
    if index>0:
        log_returns.loc[len(log_returns.index)] = log_return
    if index>3:
        vol_5.loc[len(vol_5.index)] = v_5
    if index>28:
        vol_30.loc[len(vol_30.index)] = v_30
# Out:
# 100%|██████████| 26404/26404 [29:31<00:00, 14.90it/s]

# %%
log_returns.head()
# Out:
#    TSLA_log_return  AAPL_log_return  NVDA_log_return  ORCL_log_return  \
# 0        -0.007179        -0.000686         0.000173        -0.003059
# 1         0.002042        -0.001024         0.001130        -0.001022
# 2         0.004992         0.000218         0.004221         0.001486
# 3        -0.003981        -0.002052        -0.003654         0.001298
# 4        -0.006071        -0.002253        -0.003607         0.001481
#
#    SPY_log_return  MSFT_log_return  C_log_return  FB_log_return  \
# 0        0.000030         0.000814      0.002190      -0.001316
# 1       -0.000773        -0.002540      0.002565       0.000763
# 2        0.000758         0.002492     -0.002660       0.000686
# 3       -0.000848         0.000048     -0.001714      -0.001973
# 4       -0.000268        -0.002204      0.001333      -0.002114
#
#    QQQ_log_return  AMZN_log_return  ...  INTC_log_return  PFE_log_return  \
# 0        0.000073        -0.000371  ...         0.001435        0.001315
# 1       -0.001429        -0.003007  ...        -0.000410       -0.001841
# 2        0.001466         0.001511  ...         0.001843       -0.000743
# 3       -0.000879         0.000548  ...        -0.001536        0.001006
# 4       -0.001394        -0.002560  ...         0.000000        0.000263
#
#    BAC_log_return  NFLX_log_return  MU_log_return  XOM_log_return  \
# 0        0.002300         0.000890      -0.001097        0.001426
# 1        0.002955        -0.001014      -0.001208        0.002089
# 2       -0.000088         0.004021      -0.000550        0.003736
# 3       -0.002484         0.000773      -0.002863       -0.001866
# 4        0.001530        -0.000144       0.000441        0.001633
#
#    GILD_log_return  SNAP_log_return  GE_log_return  IWM_log_return
# 0         0.001174         0.004106      -0.001530        0.001215
# 1        -0.000734        -0.000005       0.003058        0.000192
# 2         0.001980         0.001590      -0.000015        0.001086
# 3        -0.000806        -0.000454      -0.000748       -0.001597
# 4         0.000440        -0.005237       0.001527       -0.000703
#
# [5 rows x 25 columns]

# %%
vol_5.head()
# Out:
#    TSLA_vol_5  AAPL_vol_5  NVDA_vol_5  ORCL_vol_5  SPY_vol_5  MSFT_vol_5  \
# 0    0.938140    0.136928    0.925184    0.076577   0.132650    0.204490
# 1    1.103502    0.209687    1.104888    0.079725   0.155743    0.241909
# 2    1.086445    0.186601    1.154128    0.081731   0.131286    0.256796
# 3    1.168755    0.161923    1.267422    0.063056   0.142632    0.260875
# 4    0.836973    0.089451    1.284964    0.058310   0.170529    0.301423
#
#     C_vol_5  FB_vol_5  QQQ_vol_5  AMZN_vol_5  ...  INTC_vol_5  PFE_vol_5  \
# 0  0.088566  0.199030   0.158821    3.795636  ...    0.044944   0.032138
# 1  0.074673  0.365263   0.236440    4.118024  ...    0.031718   0.032138
# 2  0.086163  0.368218   0.211811    3.001680  ...    0.031718   0.022565
# 3  0.043081  0.401022   0.212941    2.787959  ...    0.029563   0.042128
# 4  0.032619  0.378062   0.233889    2.624043  ...    0.010992   0.036551
#
#    BAC_vol_5  NFLX_vol_5  MU_vol_5  XOM_vol_5  GILD_vol_5  SNAP_vol_5  \
# 0   0.051395    0.976963  0.087886   0.111764    0.058275    0.044207
# 1   0.032206    0.964782  0.080474   0.094192    0.047117    0.044207
# 2   0.027596    1.018570  0.061612   0.061838    0.055281    0.070498
# 3   0.023537    0.621292  0.066603   0.070711    0.048415    0.072553
# 4   0.018868    0.705141  0.077720   0.059174    0.058515    0.061205
#
#    GE_vol_5  IWM_vol_5
# 0  0.007465   0.126079
# 1  0.008593   0.117405
# 2  0.003737   0.129213
# 3  0.008355   0.170341
# 4  0.009517   0.103034
#
# [5 rows x 25 columns]

# %%
vol_30.head()
# Out:
#    TSLA_vol_30  AAPL_vol_30  NVDA_vol_30  ORCL_vol_30  SPY_vol_30  \
# 0     1.305705     0.362550     1.778925     0.104934    0.212408
# 1     1.241806     0.341990     1.691428     0.106750    0.220761
# 2     1.260227     0.321087     1.619430     0.101066    0.236867
# 3     1.255219     0.304867     1.549451     0.086599    0.240861
# 4     1.181466     0.284351     1.551113     0.079208    0.249831
#
#    MSFT_vol_30  C_vol_30  FB_vol_30  QQQ_vol_30  AMZN_vol_30  ...  \
# 0     0.365969  0.060673   0.643585    0.430724     8.776870  ...
# 1     0.369471  0.059500   0.631061    0.426226     8.516449  ...
# 2     0.369196  0.058914   0.627104    0.421093     8.380171  ...
# 3     0.364865  0.051651   0.616619    0.421253     8.697911  ...
# 4     0.365820  0.053572   0.597901    0.415051     8.733007  ...
#
#    INTC_vol_30  PFE_vol_30  BAC_vol_30  NFLX_vol_30  MU_vol_30  XOM_vol_30  \
# 0     0.062904    0.046381    0.036379     1.626095   0.135028    0.097937
# 1     0.061138    0.049667    0.030824     1.578571   0.135235    0.090687
# 2     0.065239    0.055480    0.029158     1.560141   0.135335    0.085950
# 3     0.066915    0.058395    0.029483     1.472857   0.134078    0.085730
# 4     0.071645    0.058821    0.029692     1.460369   0.132858    0.088217
#
#    GILD_vol_30  SNAP_vol_30  GE_vol_30  IWM_vol_30
# 0     0.076545     0.089688   0.013265    0.210908
# 1     0.080504     0.089587   0.012936    0.229076
# 2     0.086243     0.087067   0.011806    0.241550
# 3     0.088502     0.084357   0.012697    0.252277
# 4     0.090930     0.079366   0.014144    0.258733
#
# [5 rows x 25 columns]
